# %% [markdown]
# #  Indexes - How to Set, Reset, and Use Indexes

# %%
people = {
    'first' : ['Corey', 'Jane', 'John'],
    'last' : ['Schafer', 'Doe', 'Doe'],
    'email' : ['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df['email']
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
df.set_index('email')
# Out:
#                         first     last
# email
# CoreySchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com        Jane      Doe
# JohnDoe@email.com        John      Doe

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                         first     last
# email
# CoreySchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com        Jane      Doe
# JohnDoe@email.com        John      Doe

# %%
df.index
# Out:
# Index(['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df.loc['CoreySchafer@gmail.com']
# Out:
# first      Corey
# last     Schafer
# Name: CoreySchafer@gmail.com, dtype: object

# %%
df.loc['CoreySchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreySchafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                     email  first     last
# 0  CoreySchafer@gmail.com  Corey  Schafer
# 1       JaneDoe@email.com   Jane      Doe
# 2       JohnDoe@email.com   John      Doe

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_row', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['PurchaseWhat']
# Out:
# QuestionText    What level of influence do you, personally, ha...
# Name: PurchaseWhat, dtype: object

# %%
schema_df.loc['PurchaseWhat', 'QuestionText']
# Out:
# 'What level of influence do you, personally, have over new technology purchases at your organization?'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# ...

# %% [markdown]
# # Filtering - Using Conditionals to Filter Rows and Columns

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email': ['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)

# %%
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df[df['last'] == 'Doe']
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = ((df['last'] == 'Doe') & (df['first'] == 'John'))

# %%
df.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = ((df['last'] == 'Schafer') | (df['first'] == 'John'))

# %%
df.loc[filt, 'email']
# Out:
# 0    CoreySchafer@gmail.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ['united State', 'India', "United Kingdom", 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 6               Germany
# 7                 India
# 10       United Kingdom
#               ...
# 61490    United Kingdom
# 62464             India
# 62834            Canada
# 62954             India
# 64236             India
# Name: Country, Length: 18380, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %% [markdown]
# # Updating Rows and Columns - Modifying Data Within DataFrames

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email': ['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#   FIRST NAME LAST NAME                   EMAIL
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first name last name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.rename(columns={'first name':'first', 'last name':'last'}, inplace=True)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.loc[2]
# Out:
# first                 John
# last                   Doe
# email    JohnDoe@email.com
# Name: 2, dtype: object

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John    Smith     JohnSmith@email.com

# %%
df.loc[2, ['last', 'email']]
# Out:
# last                   Smith
# email    JohnSmith@email.com
# Name: 2, dtype: object

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John    Smith       JohnDoe@email.com

# %%
df.at[2, 'last'] = 'Doe'
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')

# %%
df[filt]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df[filt]['last'] = 'Smith'
# Out:
# C:\Users\Rj\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John    Smith       JohnDoe@email.com

# %%
df['email'].str.lower()
# Out:
# 0    coreyschafer@gmail.com
# 1         janedoe@email.com
# 2         johndoe@email.com
# Name: email, dtype: object

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@email.com
# 2   John    Smith       johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYSCHAFER@GMAIL.COM
# 1         JANEDOE@EMAIL.COM
# 2         JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  COREYSCHAFER@GMAIL.COM
# 1   Jane      Doe       JANEDOE@EMAIL.COM
# 2   John    Smith       JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@email.com
# 2   John    Smith       johndoe@email.com

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     22
# 1      4     3     17
# 2      4     5     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@email.com
# 2   john    smith       johndoe@email.com

# %%
df['first'].map({'Corey':'Chris', 'Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey':'Chris', 'Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey':'Chris', 'Jane':'Mary'})

# %%
df
# Out:
#    first     last                   email
# 0  Chris  Schafer  coreyschafer@gmail.com
# 1   Mary      Doe       janedoe@email.com
# 2   John    Smith       johndoe@email.com

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email': ['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd
df = pd.DataFrame(people)
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                   email      full_name
# 0  Corey  Schafer  CoreySchafer@gmail.com  Corey Schafer
# 1   Jane      Doe       JaneDoe@email.com       Jane Doe
# 2   John      Doe       JohnDoe@email.com       John Doe

# %%
df.drop(columns=['first', 'last'])
# Out:
#                     email      full_name
# 0  CoreySchafer@gmail.com  Corey Schafer
# 1       JaneDoe@email.com       Jane Doe
# 2       JohnDoe@email.com       John Doe

# %%
df.drop(columns=['first', 'last'], inplace=True)
df
# Out:
#                     email      full_name
# 0  CoreySchafer@gmail.com  Corey Schafer
# 1       JaneDoe@email.com       Jane Doe
# 2       JohnDoe@email.com       John Doe

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       JaneDoe@email.com       Jane Doe   Jane      Doe
# 2       JohnDoe@email.com       John Doe   John      Doe

# %%
df.append({'first':'Tony'}, ignore_index=True)
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       JaneDoe@email.com       Jane Doe   Jane      Doe
# 2       JohnDoe@email.com       John Doe   John      Doe
# 3                     NaN            NaN   Tony      NaN

# %%
people = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Roger'],
    'email': ['Ironman@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first   last               email
# 0   Tony  Stark  Ironman@avenge.com
# 1  Steve  Roger      Cap@avenge.com

# %%
df.append(df2, ignore_index=True)
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       JaneDoe@email.com       Jane Doe   Jane      Doe
# 2       JohnDoe@email.com       John Doe   John      Doe
# 3      Ironman@avenge.com            NaN   Tony    Stark
# 4          Cap@avenge.com            NaN  Steve    Roger

# %%
df.drop(index=df[df['last']=='Doe'].index)
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer

# %% [markdown]
# # SORT DATA

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Adam'],
    'last': ['Schafer', 'Doe', 'Doe', 'Doe'],
    'email': ['CoreySchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', 'A@email.com']
}

# %%
import pandas as pd
df = pd.DataFrame(people)
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com
# 3   Adam      Doe             A@email.com

# %%
df.sort_values(by='last')
# Out:
#    first     last                   email
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com
# 3   Adam      Doe             A@email.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com
# 3   Adam      Doe             A@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 2   John      Doe       JohnDoe@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 3   Adam      Doe             A@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 3   Adam      Doe             A@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 3   Adam      Doe             A@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com
# 3   Adam      Doe             A@email.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
df.sort_values(by='Country', inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 8631        Afghanistan            NaN
# 25001       Afghanistan            NaN
# 58171       Afghanistan            NaN
# 42668       Afghanistan            NaN
# 51509       Afghanistan        20220.0
# 37951       Afghanistan            NaN
# 28374       Afghanistan       130000.0
# 7616        Afghanistan            NaN
# 43966       Afghanistan            NaN
# 62698       Afghanistan            NaN
# 51532       Afghanistan            NaN
# 36574       Afghanistan            NaN
# 43946       Afghanistan            NaN
# 65381       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 35753       Afghanistan          780.0
# 43808       Afghanistan            NaN
# 37159       Afghanistan            NaN
# 44555       Afghanistan            NaN
# 35687       Afghanistan            NaN
# 37605       Afghanistan            NaN
# 44556       Afghanistan            NaN
# 23798       Afghanistan            NaN
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 62788       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 63848       Afghanistan        23328.0
# 9839        Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0
# 15422       Afghanistan        18000.0
# 2932        Afghanistan        16335.0
# 26540       Afghanistan        13992.0
# 57269       Afghanistan        10884.0
# 26775       Afghanistan         8016.0
# 30568       Afghanistan         5448.0
# 30522       Afghanistan         4668.0
# 28811       Afghanistan         4509.0
# 34969       Afghanistan         4356.0
# 26857       Afghanistan         2328.0
# 33878       Afghanistan         1860.0
# 35753       Afghanistan          780.0
# 18049       Afghanistan          109.0
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
 df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 54263       I am a developer by profession      Yes  29.0
# 5725        I am a developer by profession       No  26.0
# 43430       I am a developer by profession      Yes  33.0
# 59279       I am a developer by profession      Yes   NaN
# 46711       I am a developer by profession      Yes   NaN
# 1793        I am a developer by profession      Yes  27.0
# 3072        I am a developer by profession      Yes  32.0
# 3045        I am a developer by profession      Yes  35.0
# 1413        I am a developer by profession      Yes  25.0
# 3261        I am a developer by profession      Yes  34.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 54263                         10   Weekly  7.000000e+04      2000000.0
# 5725                          14  Monthly  1.800000e+05      2000000.0
# 43430                         17  Monthly  1.710000e+05      2000000.0
# ...

# %%
 df.nsmallest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession      Yes   NaN         13  Monthly
# 47357       I am a developer by profession      Yes   NaN          5   Weekly
# 27135       I am a developer by profession       No   NaN         16   Yearly
# 6054        I am a developer by profession      Yes  38.0         15   Yearly
# 60292       I am a developer by profession      Yes   NaN         12   Yearly
# 38813       I am a developer by profession       No   NaN         18  Monthly
# 8470        I am a developer by profession      Yes   NaN          5  Monthly
# 41006       I am a developer by profession      Yes  22.0         17   Yearly
# 15493       I am a developer by profession       No  44.0         17  Monthly
# 57369       I am a developer by profession       No  44.0         18  Monthly
#
#             CompTotal  ConvertedComp      Country        CurrencyDesc  \
# Respondent
# ...

# %% [markdown]
# # Grouping And Aggregation

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df.loc['PlatformWorkedWith']
# Out:
# QuestionText    Which platforms have you done extensive develo...
# Name: PlatformWorkedWith, dtype: object

# %%
df['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                                4770
# Linux;Windows                                                                                          2461
# Linux                                                                                                  2112
# Android                                                                                                1201
# Microsoft Azure;Windows                                                                                 996
#                                                                                                        ...
# Google Cloud Platform;Heroku;IBM Cloud or Watson;Linux;Raspberry Pi;Windows                               1
# Android;AWS;Docker;Google Cloud Platform;Heroku;iOS;Kubernetes;Linux;WordPress                            1
# AWS;Docker;Google Cloud Platform;Heroku;IBM Cloud or Watson;Linux;Microsoft Azure;Windows;WordPress       1
# ...

# %%
df['PlatformWorkedWith'].value_counts(normalize=True)
# Out:
# Windows                                                                                                0.088591
# Linux;Windows                                                                                          0.045707
# Linux                                                                                                  0.039225
# Android                                                                                                0.022306
# Microsoft Azure;Windows                                                                                0.018498
#                                                                                                          ...
# Google Cloud Platform;Heroku;IBM Cloud or Watson;Linux;Raspberry Pi;Windows                            0.000019
# Android;AWS;Docker;Google Cloud Platform;Heroku;iOS;Kubernetes;Linux;WordPress                         0.000019
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Liechtenstein                             1
# Nauru                                     1
# Saint Lucia                               1
# Micronesia, Federated States of...        1
# Mali                                      1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                                                                                    842
# Linux;Windows                                                                                                                                              378
# Linux                                                                                                                                                      358
# Microsoft Azure;Windows                                                                                                                                    237
# Linux;MacOS                                                                                                                                                134
#                                                                                                                                                           ...
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['WebframeWorkedWith'].value_counts()
# Out:
# jQuery                                            295
# Spring                                            205
# React.js                                          178
# Django                                            175
# ASP.NET                                           131
#                                                  ...
# Django;Laravel;Vue.js                               1
# Angular.js;ASP.NET Core;React.js;Spring             1
# Angular.js;Express;jQuery;Laravel                   1
# ASP.NET Core;Django;Express;Gatsby;React.js         1
# Angular;Angular.js;Drupal;jQuery;Spring;Vue.js      1
# Name: WebframeWorkedWith, Length: 985, dtype: int64

# %%
country_grp['WebframeWorkedWith'].value_counts().head(50)
# Out:
# Country      WebframeWorkedWith
# Afghanistan  Angular                                                                                                                                   5
#              jQuery                                                                                                                                    5
#              ASP.NET;jQuery;Laravel                                                                                                                    3
#              Laravel                                                                                                                                   2
#              jQuery;Laravel                                                                                                                            2
#              jQuery;Laravel;Vue.js                                                                                                                     2
# ...

# %%
country_grp['WebframeWorkedWith'].value_counts().loc['India']
# Out:
# WebframeWorkedWith
# jQuery                                         295
# Spring                                         205
# React.js                                       178
# Django                                         175
# ASP.NET                                        131
#                                               ...
# jQuery;React.js;Ruby on Rails;Spring             1
# jQuery;React.js;Ruby on Rails;Spring;Vue.js      1
# jQuery;React.js;Ruby on Rails;Vue.js             1
# jQuery;Ruby on Rails;Spring                      1
# jQuery;Spring;Symfony                            1
# Name: WebframeWorkedWith, Length: 985, dtype: int64

# %%
country_grp['WebframeWorkedWith'].value_counts().loc['China']
# Out:
# WebframeWorkedWith
# Django                           11
# jQuery                           11
# Vue.js                           10
# Flask                             9
# React.js;Vue.js                   9
#                                  ..
# Ruby on Rails;Vue.js              1
# jQuery;Laravel;Spring;Vue.js      1
# jQuery;Laravel;Vue.js             1
# jQuery;React.js;Spring;Vue.js     1
# jQuery;Symfony                    1
# Name: WebframeWorkedWith, Length: 108, dtype: int64

# %%
country_grp['WebframeWorkedWith'].value_counts().loc['Russian Federation']
# Out:
# WebframeWorkedWith
# jQuery                                  43
# React.js                                41
# Spring                                  36
# Flask                                   35
# Django                                  28
#                                         ..
# jQuery;React.js;Ruby on Rails;Vue.js     1
# jQuery;Ruby on Rails;Vue.js              1
# jQuery;Spring;Symfony                    1
# jQuery;Symfony;Vue.js                    1
# jQuery;Vue.js                            1
# Name: WebframeWorkedWith, Length: 247, dtype: int64

# %%
country_grp['WebframeWorkedWith'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# WebframeWorkedWith
# jQuery                                  0.063609
# React.js                                0.060651
# Spring                                  0.053254
# Flask                                   0.051775
# Django                                  0.041420
#                                           ...
# jQuery;React.js;Ruby on Rails;Vue.js    0.001479
# jQuery;Ruby on Rails;Vue.js             0.001479
# jQuery;Spring;Symfony                   0.001479
# jQuery;Symfony;Vue.js                   0.001479
# jQuery;Vue.js                           0.001479
# Name: WebframeWorkedWith, Length: 247, dtype: float64

# %%
country_grp['WebframeWorkedWith'].value_counts(normalize=True).loc['China']
# Out:
# WebframeWorkedWith
# Django                           0.051643
# jQuery                           0.051643
# Vue.js                           0.046948
# Flask                            0.042254
# React.js;Vue.js                  0.042254
#                                    ...
# Ruby on Rails;Vue.js             0.004695
# jQuery;Laravel;Spring;Vue.js     0.004695
# jQuery;Laravel;Vue.js            0.004695
# jQuery;React.js;Spring;Vue.js    0.004695
# jQuery;Symfony                   0.004695
# Name: WebframeWorkedWith, Length: 108, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 7                                  C#;HTML/CSS;PHP
# 22                                     Java;Python
# 58                    C#;JavaScript;SQL;TypeScript
# 63           C;C++;HTML/CSS;Java;JavaScript;Python
# 149                 Bash/Shell/PowerShell;C++;Perl
#                            ...
# 54757    C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 55407                                          NaN
# 62464                                          NaN
# 62954                                          SQL
# 64236                                          NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 7        False
# 22        True
# 58       False
# 63        True
# 149      False
#          ...
# 54757     True
# 55407      NaN
# 62464      NaN
# 62954    False
# 64236      NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# What % of people from each country know Python?

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Liechtenstein                             1
# Nauru                                     1
# Saint Lucia                               1
# Micronesia, Federated States of...        1
# Mali                                      1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Liechtenstein                             1                   0
# Nauru                                     1                   0
# Saint Lucia                               1                   1
# Micronesia, Federated States of...        1                   1
# Mali                                      1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': "NumRespondents", "LanguageWorkedWith": "NumKnowsPython"}, inplace=True)

# %%
python_df
# Out:
#                                     NumRespondents  NumKnowsPython
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Liechtenstein                                    1               0
# Nauru                                            1               0
# Saint Lucia                                      1               1
# Micronesia, Federated States of...               1               1
# Mali                                             1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Liechtenstein                                    1               0
# Nauru                                            1               0
# Saint Lucia                                      1               1
# Micronesia, Federated States of...               1               1
# Mali                                             1               0
#
#                                     PctKnowsPython
# United States                            47.830620
# India                                    31.774366
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Gabon                                              1               1
# Micronesia, Federated States of...                 1               1
# Saint Lucia                                        1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Mauritania                                         4               2
# Papua New Guinea                                   2               1
# Burkina Faso                                       6               3
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64

# %% [markdown]
# # Cleaning Data - Missing Values & Casting DataType

# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'HohnDoe@email.com', None, np.nan, 'Anonymous@emai.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all', subset=['last' ,'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        HohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN       Anonymous@emai.com     None
# 6     NA  Missing                       NA  Missing

# %%
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        HohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN       Anonymous@emai.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        HohnDoe@email.com  63

# %%
df.dropna(axis='index', how = 'all', subset=['last', 'email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        HohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN       Anonymous@emai.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        HohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING       Anonymous@emai.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        HohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0       Anonymous@emai.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f17fc7aadc36> in <module>
# ----> 1 df['age'].mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11468         return self._reduce(
# > 11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#   11471
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df['age'] = df['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-9b0df8191b9d> in <module>
# ----> 1 df['age'] = df['age'].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ...

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75

# %%
schema_df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_schema.csv', index_col = 'Column')
df = pd.read_csv('C:/Users/Rj/Downloads/stack-overflow-developer-survey-2020/survey_results_public.csv', index_col='Respondent')

# %%
na_vals = ['NA', 'Missing']

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
#df['YearCode'].mean()
#df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %% [markdown]
# # Date & Time Series Data

# %%
df = pd.read_csv(r'C:/Users/Rj/Downloads/ETH_1h.csv')
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-55e7fa569c9a> in <module>
# ----> 1 df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv(r'C:/Users/Rj/Downloads/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# C:\Users\Rj\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date']>='2020')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = (df['Date']>='2019')
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt = (df['Date']>='2019') & (df["Date"] < '2020')
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt = (df['Date']>=pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
df.loc['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df.loc['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df.loc['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
df.loc['2020-01':'2020-02'].head()
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
#
#                     DayOfWeek
# Date
# 2020-02-29 23:00:00  Saturday
# 2020-02-29 22:00:00  Saturday
# 2020-02-29 21:00:00  Saturday
# 2020-02-29 20:00:00  Saturday
# 2020-02-29 19:00:00  Saturday

# %%
df.loc['2020-01-01']['High']
# Out:
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# 2020-01-01 03:00:00    130.44
# 2020-01-01 02:00:00    130.50
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.54
# Name: High, dtype: float64

# %%
df.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
df['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('w').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df.resample('w').agg({'Close': 'mean', 'High':'max', 'Low' :'min', 'Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# # Writing/Reading Data to different Source
